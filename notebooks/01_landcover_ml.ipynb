# %% [markdown]
# # Land-cover ML with spatial validation
# Synthetic demonstration workflow only.

# %%
from src.data_generation import generate_landcover
from src.modeling import train_spatial_holdout
df=generate_landcover()
model,metrics=train_spatial_holdout(df)
metrics
